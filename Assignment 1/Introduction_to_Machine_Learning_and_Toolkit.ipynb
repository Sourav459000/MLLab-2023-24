# %% [markdown]
# # Introduction to Machine Learning and Toolkit Exercises

# %% [markdown]
# # What is Machine Learning?
#
# | This | is   |
# |------|------|
# |   Machine learning allows computers to learn and infer from data.  | ![robot.png](Assets/robot.png)|

# %% [markdown]
# # Learning Objectives
#
# - Demonstrate supervised learning algorithms
# - Explain key concepts like under- and over-fitting, regularization, and cross-validation
# - Classify the type of problem to be solved, choose the right algorithm, tune parameters, and validate a model
# - Apply Intel® Extension for Scikit-learn* to leverage underlying compute capabilities of hardware

# %% [markdown]
# # Overview of Course:
#
# ### Topics include:
#
# - Introduction and exploratory analysis (Week 1)
# - Supervised machine learning (Weeks 2 – 10)
# - Unsupervised machine learning (Weeks 11 – 12)
#
# ### Prerequisites:
#
# - Python* programming
# - Calculus
# - Linear algebra
# - Statistics
#
# ### Lab Preparation:
# - pip install -r ../requirements.txt
#
# ### Our Toolset: Intel® oneAPI AI Analytics Toolkit (AI Kit)
# - Intel® Extension for Scikit-learn*
#
# ### Intel® oneAPI Toolkits Installation
# The [following documents](https://software.intel.com/content/www/us/en/develop/articles/installation-guide-for-intel-oneapi-toolkits.html) provide detailed instructions on how to get and install Intel® oneAPI packages using different installer modes and package managers:
#
# - [Intel® oneAPI Toolkits Installation Guide for Linux* OS](https://software.intel.com/content/www/us/en/develop/documentation/installation-guide-for-intel-oneapi-toolkits-linux/top.html)
# - [Intel® oneAPI Toolkits Installation Guide for Windows*](https://software.intel.com/content/www/us/en/develop/documentation/installation-guide-for-intel-oneapi-toolkits-windows/top.html)
# - [Intel® oneAPI Toolkits Installation Guide for macOS*](https://software.intel.com/content/www/us/en/develop/documentation/installation-guide-for-intel-oneapi-toolkits-macos/top.html)

# %% [markdown]
# ## Introduction
#
# We will be using the iris data set for this tutorial. This is a well-known data set containing iris species and sepal and petal measurements. The data we will use are in a file called `Iris_Data.csv` found in the [data](../../data) directory.

# %%
pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (4.66.2)
# Requirement already satisfied: seaborn in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: openpyxl in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: Pillow in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (10.2.0)
# Requirement already satisfied: nbconvert in /srv/jupyter/python-venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (7.8.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from seaborn->-r ../requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from seaborn->-r ../requirements.txt (line 3)) (2.2.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from seaborn->-r ../requirements.txt (line 3)) (3.8.3)
# Requirement already satisfied: et-xmlfile in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from openpyxl->-r ../requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: defusedxml in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: jupyter-core>=4.7 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (5.3.1)
# Requirement already satisfied: jupyterlab-pygments in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (5.9.2)
# Requirement already satisfied: packaging in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (2.16.1)
# Requirement already satisfied: tinycss2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: traitlets>=5.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbconvert->-r ../requirements.txt (line 6)) (5.10.0)
# Requirement already satisfied: six>=1.9.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->-r ../requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: webencodings in /srv/jupyter/python-venv/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->-r ../requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-core>=4.7->nbconvert->-r ../requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 3)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 3)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ../requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbclient>=0.5.0->nbconvert->-r ../requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: fastjsonschema in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->-r ../requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from nbformat>=5.7->nbconvert->-r ../requirements.txt (line 6)) (4.19.1)
# Requirement already satisfied: pytz>=2020.1 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn->-r ../requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ub9232b6b54ae16db5cdf27dd3f53c3d/.local/lib/python3.11/site-packages (from pandas>=1.2->seaborn->-r ../requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: soupsieve>1.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->-r ../requirements.txt (line 6)) (2.5)
# Requirement already satisfied: attrs>=22.2.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->-r ../requirements.txt (line 6)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->-r ../requirements.txt (line 6)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->-r ../requirements.txt (line 6)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->-r ../requirements.txt (line 6)) (0.10.3)
# Requirement already satisfied: pyzmq>=23.0 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->-r ../requirements.txt (line 6)) (25.1.1)
# Requirement already satisfied: tornado>=6.2 in /srv/jupyter/python-venv/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert->-r ../requirements.txt (line 6)) (6.3.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: /srv/jupyter/python-venv/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import print_function
import os
data_path = [ '../data']

# %% [markdown]
# # scikit-learn*
#
# Frameworks provide structure that Data Scientists use to build code. Frameworks are more than just libraries, because in addition to callable code, frameworks influence how code is written.
#
# A main virtue of using an optimized framework is that code runs faster. Code that runs faster is just generally more convenient but when we begin looking at applied data science and AI models, we can see more material benefits. Here you will see how optimization, particularly hyperparameter optimization can benefit more than just speed.
#
# These exercises will demonstrate how to apply **the Intel® Extension for Scikit-learn*,** a seamless way to speed up your Scikit-learn application. The acceleration is achieved through the use of the Intel® oneAPI Data Analytics Library (oneDAL). Patching is the term used to extend scikit-learn with Intel optimizations and makes it a well-suited machine learning framework for dealing with real-life problems.
#
# To get optimized versions of many Scikit-learn algorithms using a patch() approach consisting of adding these lines of code Prior to importing sklearn:
#
# - **from sklearnex import patch_sklearn**
# - **patch_sklearn()**

# %% [markdown]
# ## Question 1
#
# Load the data from the file (data/Iris_Data.csv) using the techniques learned today. Examine it.
#
# Determine the following:
#
# * The number of data points (rows). (*Hint:* check out the dataframe `.shape` attribute.)
# * The column names. (*Hint:* check out the dataframe `.columns` attribute.)
# * The data types for each column. (*Hint:* check out the dataframe `.dtypes` attribute.)

# %%
import pandas as pd

df = pd.read_csv('data/Iris_Data.csv')
print(f'Rows x Columns: {df.shape}\n')
print(f'Columns: {df.columns}\n')
print(f'Data types for each columns:\n\n{df.dtypes}')
# Out:
# Rows x Columns: (150, 5)
#
# Columns: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#
# Data types for each columns:
#
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ## Question 2
#
# Examine the species names and note that they all begin with 'Iris-'. Remove this portion of the name so the species name is shorter.
#
# *Hint:* there are multiple ways to do this, but you could use either the [string processing methods](http://pandas.pydata.org/pandas-docs/stable/text.html) or the [apply method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html).

# %%
df['species'] = df['species'].str.replace('Iris-','')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Question 3
#
# Determine the following:
# * The number of each species present. (*Hint:* check out the series `.value_counts` method.)
# * The mean, median, and quantiles and ranges (max-min) for each petal and sepal measurement.
#
# *Hint:* for the last question, the `.describe` method does have median, but it's not called median. It's the *50%* quantile. `.describe` does not have range though, and in order to get the range, you will need to create a new entry in the `.describe` table, which is `max - min`.

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Question 4
#
# Calculate the following **for each species** in a separate dataframe:
#
# * The mean of each measurement (sepal_length, sepal_width, petal_length, and petal_width).
# * The median of each of these measurements.
#
# *Hint:* you may want to use Pandas [`groupby` method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html) to group by species before calculating the statistic.
#
# If you finish both of these, try calculating both statistics (mean and median) in a single table (i.e. with a single groupby call). See the section of the Pandas documentation on [applying multiple functions at once](http://pandas.pydata.org/pandas-docs/stable/groupby.html#applying-multiple-functions-at-once) for a hint.

# %%
df.groupby(['species']).mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df.groupby(['species']).median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %% [markdown]
# ## Question 5
#
# Make a scatter plot of `sepal_length` vs `sepal_width` using Matplotlib. Label the axes and give the plot a title.

# %%
import matplotlib.pyplot as plt

plt.scatter(df['sepal_length'], df['sepal_width'])
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Scatter plot of sepal_length vs sepal_width')
plt.show()

# %% [markdown]
# ## Question 6
#
# Make a histogram of any one of the four features. Label axes and title it as appropriate.

# %%
plt.hist(df['sepal_length'])
plt.xlabel('Sepal length')
plt.ylabel('count')
plt.title('Sepal')
plt.show()

# %% [markdown]
# ## Question 7
#
# Now create a single plot with histograms for each feature (`petal_width`, `petal_length`, `sepal_width`, `sepal_length`) overlayed. If you have time, next try to create four individual histogram plots in a single figure, where each plot contains one feature.
#
# For some hints on how to do this with Pandas plotting methods, check out the [visualization guide](http://pandas.pydata.org/pandas-docs/version/0.18.1/visualization.html) for Pandas.

# %%
plt.hist([df['petal_width'], df['petal_length'], df['sepal_width'], df['sepal_length']])
plt.show()

# %% [markdown]
# ## Question 8
#
# Using Pandas, make a boxplot of each petal and sepal measurement. Here is the documentation for [Pandas boxplot method](http://pandas.pydata.org/pandas-docs/version/0.18.1/visualization.html#visualization-box).

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ## Question 9
#
# Now make a single boxplot where the features are separated in the x-axis and species are colored with different hues.
#
# *Hint:* you may want to check the documentation for [Seaborn boxplots](http://seaborn.pydata.org/generated/seaborn.boxplot.html).
#
# Also note that Seaborn is very picky about data format--for this plot to work, the input dataframe will need to be manipulated so that each row contains a single data point (a species, a measurement type, and the measurement value). Check out Pandas [stack](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.stack.html) method as a starting place.
#
# Here is an example of a data format that will work:
#
# |   | species | measurement  | size |
# | - | ------- | ------------ | ---- |
# | 0	| setosa  | sepal_length | 5.1  |
# | 1	| setosa  | sepal_width  | 3.5  |

# %%
import seaborn as sns

melted_df = pd.melt(df, id_vars=['species'], value_vars=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], var_name='measurement')

plt.figure(figsize=(10, 6))
sns.boxplot(x='measurement', y='value', hue='species', data=melted_df)
plt.title('Boxplot of Iris Dataset Features by Species')
plt.xlabel('Feature')
plt.ylabel('Measurement')
plt.show()

# %% [markdown]
# ## Question 10
#
# Make a [pairplot](http://seaborn.pydata.org/generated/seaborn.pairplot.html) with Seaborn to examine the correlation between each of the measurements.
#
# *Hint:* this plot may look complicated, but it is actually only a single line of code. This is the power of Seaborn and dataframe-aware plotting! See the lecture notes for reference.

# %%
sns.pairplot(df)
